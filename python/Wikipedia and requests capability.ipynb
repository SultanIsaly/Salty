# %%
import wikipedia
wikipedia.search("Chess")
# Out:
# ['Chess',
#  'Chess (disambiguation)',
#  'Chess club',
#  'List of chess software',
#  'The Oxford Companion to Chess',
#  'Chess set',
#  'Chess equipment',
#  'Norm (chess)',
#  'Overloading (chess)',
#  'Chess title']

# %%
wikipedia.search("Literature",2)
# Out:
# ['Literature', 'Western literature']

# %%
wikipedia.search("Literature",20)
# Out:
# ['Literature',
#  'Western literature',
#  '13th century in literature',
#  '14th century in literature',
#  'LGBT literature',
#  '15th century in literature',
#  'List of Nobel laureates in Literature',
#  'Table of years in literature',
#  'Old Norse literature',
#  'Benin literature',
#  'Welsh literature',
#  'Solomon Islands literature',
#  'Slavic literature',
#  'Pashto literature and poetry',
#  'Nobel Prize in Literature',
#  'Contemporary literature',
#  'Kazakh literature',
#  'Texas literature',
#  'Taiwanese literature',
#  'Asian literature']

# %%
wikipedia.suggest("Literatre")
# Out:
# 'literature'

# %%
wikipedia.suggest("Literature")

# %%
wikipedia.summary("Literature")
# Out:
# 'Literature consists of written productions, often restricted to those deemed to have artistic or intellectual value. Its Latin root literatura/litteratura (derived itself from littera, letter or handwriting) was used to refer to all written accounts, but intertwined with the roman concept of cultura: learning or cultivation. Literature often uses language differently than ordinary language (see literariness). Literature can be classified according to whether it is fiction or non-fiction and whether it is poetry or prose; it can be further distinguished according to major forms such as the novel, short story or drama; and works are often categorised according to historical periods or their adherence to certain aesthetic features or expectations (genre).\nThe concept has changed meaning over time: nowadays it can broaden to include non-written verbal art forms, and thus it is difficult to agree on its origin, which can be paired with that of language or writing itself. Developments in
# ...

# %%
wikipedia.summary("Literature",2)
# Out:
# 'Literature consists of written productions, often restricted to those deemed to have artistic or intellectual value. Its Latin root literatura/litteratura (derived itself from littera, letter or handwriting) was used to refer to all written accounts, but intertwined with the roman concept of cultura: learning or cultivation.'

# %%
wikipedia.summary("Literature",4)
# Out:
# 'Literature consists of written productions, often restricted to those deemed to have artistic or intellectual value. Its Latin root literatura/litteratura (derived itself from littera, letter or handwriting) was used to refer to all written accounts, but intertwined with the roman concept of cultura: learning or cultivation. Literature often uses language differently than ordinary language (see literariness). Literature can be classified according to whether it is fiction or non-fiction and whether it is poetry or prose; it can be further distinguished according to major forms such as the novel, short story or drama; and works are often categorised according to historical periods or their adherence to certain aesthetic features or expectations (genre).'

# %%
wikipedia.summary("Litefatur",4)
# Out:
# 'Literature consists of written productions, often restricted to those deemed to have artistic or intellectual value. Its Latin root literatura/litteratura (derived itself from littera, letter or handwriting) was used to refer to all written accounts, but intertwined with the roman concept of cultura: learning or cultivation. Literature often uses language differently than ordinary language (see literariness). Literature can be classified according to whether it is fiction or non-fiction and whether it is poetry or prose; it can be further distinguished according to major forms such as the novel, short story or drama; and works are often categorised according to historical periods or their adherence to certain aesthetic features or expectations (genre).'

# %%
wikipedia.page("Literature")
# Out:
# <WikipediaPage 'Literature'>

# %%
wikipedia.page("Literatur")
# Out:
# <WikipediaPage 'Literature'>

# %%
a = wikipedia.page("Literatare")

# %%
wikipedia.geosearch(2, 5, "Literat", results=10, radius=1000)
# Out:
# []

# %%
a.categories
# Out:
# ['All articles to be expanded',
#  'Articles containing traditional Chinese-language text',
#  'Articles to be expanded from February 2014',
#  'Articles with limited geographic scope from February 2014',
#  'Fiction',
#  'Literature',
#  'Main topic classifications',
#  'Pages containing links to subscription-only content',
#  'Pages using citations with accessdate and no URL',
#  'United Kingdom-centric',
#  'Wikipedia articles with GND identifiers']

# %%
a.content
# Out:
# 'Literature consists of written productions, often restricted to those deemed to have artistic or intellectual value. Its Latin root literatura/litteratura (derived itself from littera, letter or handwriting) was used to refer to all written accounts, but intertwined with the roman concept of cultura: learning or cultivation. Literature often uses language differently than ordinary language (see literariness). Literature can be classified according to whether it is fiction or non-fiction and whether it is poetry or prose; it can be further distinguished according to major forms such as the novel, short story or drama; and works are often categorised according to historical periods or their adherence to certain aesthetic features or expectations (genre).\nThe concept has changed meaning over time: nowadays it can broaden to include non-written verbal art forms, and thus it is difficult to agree on its origin, which can be paired with that of language or writing itself. Developments in
# ...

# %%
a.html()
# Out:
# '<div role="note" class="hatnote">This article is about the art of written work.&#32;&#32;For the card game, see <a href="/wiki/Literature_(card_game)" title="Literature (card game)">Literature (card game)</a>.&#32;&#32;For literature in the field technical publications, see <a href="/wiki/Academic_publishing" title="Academic publishing">Academic publishing</a>.</div>\n<div class="thumb tright"><div class="thumbinner" style="width:302px;"><a href="/wiki/File:Liji.jpg" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/68/Liji.jpg/300px-Liji.jpg" width="300" height="207" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/68/Liji.jpg/450px-Liji.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/68/Liji.jpg/600px-Liji.jpg 2x" data-file-width="2391" data-file-height="1648" /></a>  <div class="thumbcaption"><div class="magnify"><a href="/wiki/File:Liji.jpg" class="internal" title="Enlarge"></a></div>The <i><a href="/wiki/Book_o
# ...

# %%
a.images
# Out:
# ['https://upload.wikimedia.org/wikipedia/commons/b/bd/Ambox_globe_content.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/a/a4/P_literature.gif',
#  'https://upload.wikimedia.org/wikipedia/commons/1/1b/Wikiversity-logo-en.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/a/a8/Office-book.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/a/a0/Johann_Heinrich_Wilhelm_Tischbein_-_Goethe_in_the_Roman_Campagna_-_Google_Art_Project.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/4b/Books-aj.svg_aj_ashton_01.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/f/f8/Wiktionary-logo-en.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/49/LuxorTemple03.jpg',
#  'https://upload.wikimedia.org/wikipedia/commons/9/9a/Nuvola_apps_kmessedwords.png',
#  'https://upload.wikimedia.org/wikipedia/en/4/4a/Commons-logo.svg',
#  'https://upload.wikimedia.org/wikipedia/commons/4/4c/Wikisource-logo.svg',
# ...

# %%
a.links
# Out:
# ['18th century in literature',
#  '19th century in literature',
#  '20th century in literature',
#  '21st century in literature',
#  'Academic publishing',
#  'Adventure fiction',
#  'Aeschylus',
#  'Aesthetics',
#  'Age of Reason',
#  'Akkadian literature',
#  'Albanian folk poetry',
#  'Alfred Nobel',
#  'Allegory',
#  'Alternate history',
#  'American Council of Learned Societies',
#  'American poetry',
#  'Ancient Egypt',
#  'Ancient Egyptian literature',
#  'Ancient Greece',
#  'Ancient Greek comedy',
#  'Ancient Greek literature',
#  'Ancient India',
#  'Ancient literature',
#  'Antagonist',
#  'Anthropology',
#  'Antihero',
#  'Anton Chekhov',
#  'Arabic literature',
#  'Arabic poetry',
#  'Archenemy',
#  'Aristophanes',
#  'Aristotle',
#  'Armenian literature',
#  'Articulation (sociology)',
#  'Asemic writing',
#  'Assemblage (composition)',
#  'Audience',
#  'Augustine of Hippo',
#  'Australian poetry',
#  'Author',
#  'Avesta',
#  'Babylon',
#  'Backstory',
# ...

# %%
a.parent_id
# Out:
# 701245178

# %%
a.references
# Out:
# ['http://commons.wikimedia.org/wiki/Special:Search/Literature',
#  'http://dx.doi.org/10.1007%2FBF01511303',
#  'http://dx.doi.org/10.1017%2Fs0041977x00094842',
#  'http://dx.doi.org/10.1353%2Felh.1996.0019',
#  'http://dx.doi.org/10.1525%2Frh.2005.23.4.303',
#  'http://dx.doi.org/10.2307%2F2847021',
#  'http://en.wikibooks.org/wiki/Special:Search/Literature',
#  'http://en.wikinews.org/wiki/Special:Search/Literature',
#  'http://en.wikiquote.org/wiki/Special:Search/Literature',
#  'http://en.wikisource.org/wiki/Special:Search/Literature',
#  'http://en.wikiversity.org/wiki/Special:Search/Literature',
#  'http://en.wiktionary.org/wiki/Special:Search/Literature',
#  'http://tools.wmflabs.org/ftl/cgi-bin/ftl?st=wp&su=Literature',
#  'http://academic.brooklyn.cuny.edu/english/melani/cs6/novel.html',
#  'http://d-nb.info/gnd/4035964-5',
#  'http://dlibrary.acu.edu.au/staffhome/siryan/academy/foundation/what_is_literature.htm',
# ...

# %%
b = a.revision_id
# Out:
# 701327416

# %%
a.sections
# Out:
# []

# %%
a.section("Definitions")
# Out:
# 'There have been various attempts to define "literature". Simon and Delyse Ryan begin their attempt to answer the question "What is Literature?" with the observation:\n\nThe quest to discover a definition for "literature" is a road that is much travelled, though the point of arrival, if ever reached, is seldom satisfactory. Most attempted definitions are broad and vague, and they inevitably change over time. In fact, the only thing that is certain about defining literature is that the definition will change. Concepts of what is literature change over time as well.\n\nDefinitions of literature have varied over time; it is a "culturally relative definition". In Western Europe prior to the eighteenth century, literature as a term indicated all books and writing. A more restricted sense of the term emerged during the Romantic period, in which it began to demarcate "imaginative" literature. Contemporary debates over what constitutes literature can be seen as returning to the older, more i
# ...

# %%
a.summary
# Out:
# 'Literature consists of written productions, often restricted to those deemed to have artistic or intellectual value. Its Latin root literatura/litteratura (derived itself from littera, letter or handwriting) was used to refer to all written accounts, but intertwined with the roman concept of cultura: learning or cultivation. Literature often uses language differently than ordinary language (see literariness). Literature can be classified according to whether it is fiction or non-fiction and whether it is poetry or prose; it can be further distinguished according to major forms such as the novel, short story or drama; and works are often categorised according to historical periods or their adherence to certain aesthetic features or expectations (genre).\nThe concept has changed meaning over time: nowadays it can broaden to include non-written verbal art forms, and thus it is difficult to agree on its origin, which can be paired with that of language or writing itself. Developments in
# ...

# %%
wikipedia.languages()
# Out:
# {'aa': 'Qafár af',
#  'ab': 'Аҧсшәа',
#  'ace': 'Acèh',
#  'ady': 'адыгабзэ',
#  'ady-cyrl': 'адыгабзэ',
#  'aeb': 'تونسي/Tûnsî',
#  'aeb-arab': 'تونسي',
#  'aeb-latn': 'Tûnsî',
#  'af': 'Afrikaans',
#  'ak': 'Akan',
#  'aln': 'Gegë',
#  'als': 'Alemannisch',
#  'am': 'አማርኛ',
#  'an': 'aragonés',
#  'ang': 'Ænglisc',
#  'anp': 'अङ्गिका',
#  'ar': 'العربية',
#  'arc': 'ܐܪܡܝܐ',
#  'arn': 'mapudungun',
#  'arq': 'جازايرية',
#  'ary': 'Maġribi',
#  'arz': 'مصرى',
#  'as': 'অসমীয়া',
#  'ase': 'American sign language',
#  'ast': 'asturianu',
#  'av': 'авар',
#  'avk': 'Kotava',
#  'awa': 'अवधी',
#  'ay': 'Aymar aru',
#  'az': 'azərbaycanca',
#  'azb': 'تۆرکجه',
#  'ba': 'башҡортса',
#  'bar': 'Boarisch',
#  'bat-smg': 'žemaitėška',
#  'bbc': 'Batak Toba',
#  'bbc-latn': 'Batak Toba',
#  'bcc': 'جهلسری بلوچی',
#  'bcl': 'Bikol Central',
#  'be': 'беларуская',
#  'be-tarask': 'беларуская (тарашкевіца)\u200e',
#  'be-x-old': 'беларуская (тарашкевіца)\u200e',
#  'bg': 'български',
# ...

# %%
wikipedia.set_lang("ru")

# %%
wikipedia.search("Литература")
# Out:
# ['Литература',
#  'Восточная литература (издательство)',
#  'Иностранная литература',
#  'Латышская литература',
#  'Еврейская литература',
#  'Тибетская литература',
#  'Татарская литература',
#  'Литература Нигерии',
#  'Хорватская литература',
#  'Gemeinsame Normdatei']

# %%
import requests

# %%
resp = requests.get('https://ru.wikipedia.org/wiki/Литература')

# %%
resp = requests.put("http://httpbin.org/put")
resp = requests.delete("http://httpbin.org/delete")
resp = requests.head("http://httpbin.org/get")
resp = requests.options("http://httpbin.org/get")

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
resp = requests.get("http://httpbin.org/get", params=payload)

# %%
resp.url
# Out:
# 'http://httpbin.org/get?key2=value2&key1=value1'

# %%
response = requests.get('https://ru.wikipedia.org/wiki/Литература') 
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru" dir="ltr" class="client-nojs">\n<head>\n<meta charset="UTF-8" />\n<title>Литература — Википедия</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ = window.RLQ || []).push(function () {\nmw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Литература","wgTitle":"Литература","wgCurRevisionId":76634724,"wgRevisionId":76634724,"wgArticleId":193,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Статьи со ссылками на Викисловарь","Статьи со ссылками на Викиучебник","Статьи со ссылками на Викицитатник","Статьи со ссылками на Викитеку","Статьи со ссылками на Викиновости","Статьи со ссылками на проекты","Литература","Гуманитарные науки"],"wgBreakFrames":false,"wgPageContentLanguage":"ru","wgPageContentModel":"wikit
# ...

# %%
response.encoding
# Out:
# 'UTF-8'

# %%
response.encoding = 'ISO-8859-1'

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru" dir="ltr" class="client-nojs">\n<head>\n<meta charset="UTF-8" />\n<title>Ð\x9bÐ¸Ñ\x82ÐµÑ\x80Ð°Ñ\x82Ñ\x83Ñ\x80Ð° â\x80\x94 Ð\x92Ð¸ÐºÐ¸Ð¿ÐµÐ´Ð¸Ñ\x8f</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ = window.RLQ || []).push(function () {\nmw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Ð\x9bÐ¸Ñ\x82ÐµÑ\x80Ð°Ñ\x82Ñ\x83Ñ\x80Ð°","wgTitle":"Ð\x9bÐ¸Ñ\x82ÐµÑ\x80Ð°Ñ\x82Ñ\x83Ñ\x80Ð°","wgCurRevisionId":76634724,"wgRevisionId":76634724,"wgArticleId":193,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Ð¡Ñ\x82Ð°Ñ\x82Ñ\x8cÐ¸ Ñ\x81Ð¾ Ñ\x81Ñ\x81Ñ\x8bÐ»ÐºÐ°Ð¼Ð¸ Ð½Ð° Ð\x92Ð¸ÐºÐ¸Ñ\x81Ð»Ð¾Ð²Ð°Ñ\x80Ñ\x8c","Ð¡Ñ\x82Ð°Ñ\x82Ñ\x8cÐ¸ Ñ\x81Ð¾ Ñ\x81Ñ\x81Ñ\x8bÐ»ÐºÐ°Ð¼Ð¸ Ð½Ð° Ð\x92Ð¸ÐºÐ¸Ñ\x83Ñ\x87ÐµÐ±Ð½Ð¸Ðº","Ð¡Ñ\x82Ð°Ñ\x82Ñ\x8cÐ¸ 
# ...

# %%
response.encoding = 'UTF-8'

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html lang="ru" dir="ltr" class="client-nojs">\n<head>\n<meta charset="UTF-8" />\n<title>\xd0\x9b\xd0\xb8\xd1\x82\xd0\xb5\xd1\x80\xd0\xb0\xd1\x82\xd1\x83\xd1\x80\xd0\xb0 \xe2\x80\x94 \xd0\x92\xd0\xb8\xd0\xba\xd0\xb8\xd0\xbf\xd0\xb5\xd0\xb4\xd0\xb8\xd1\x8f</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ = window.RLQ || []).push(function () {\nmw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"\xd0\x9b\xd0\xb8\xd1\x82\xd0\xb5\xd1\x80\xd0\xb0\xd1\x82\xd1\x83\xd1\x80\xd0\xb0","wgTitle":"\xd0\x9b\xd0\xb8\xd1\x82\xd0\xb5\xd1\x80\xd0\xb0\xd1\x82\xd1\x83\xd1\x80\xd0\xb0","wgCurRevisionId":76634724,"wgRevisionId":76634724,"wgArticleId":193,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["\xd0\xa1\xd1\x82\xd0\xb0\xd1\x82\xd1\
# ...

# %%
response = requests.get('https://api.github.com/events') 
>>> response.json()
# Out:
# [{'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/10408784?',
#    'gravatar_id': '',
#    'id': 10408784,
#    'login': 'J-Weeks',
#    'url': 'https://api.github.com/users/J-Weeks'},
#   'created_at': '2016-02-22T19:33:29Z',
#   'id': '3674358771',
#   'payload': {'before': '66ffa94e0682b354e56e138a8ed77f6106ad57cb',
#    'commits': [{'author': {'email': 'erdesi90562@gmail.com', 'name': 'Ethan'},
#      'distinct': True,
#      'message': 'alter git ingore file to not include secrets.',
#      'sha': '23666bc65fb4b69f1aa2b0344bed2212c5c01de1',
#      'url': 'https://api.github.com/repos/J-Weeks/pongbook/commits/23666bc65fb4b69f1aa2b0344bed2212c5c01de1'},
#     {'author': {'email': 'erdesi90562@gmail.com', 'name': 'Ethan'},
#      'distinct': True,
#      'message': 'update Gemfile in order to get rspec working for tests.',
#      'sha': 'f286eb953aba6b810798bc6f319cdd0742c43221',
# ...

# %%
response = requests.get('https://ru.wikipedia.org/wiki/Литература') 
response.raw

# %%
response.raw.read(10)
# Out:
# b''

# %%
import json
url = 'https://api.github.com/some/endpoint'
payload = {'some': 'data'} 
headers = {'content-type': 'application/json'}
resposne = requests.post(url, data=json.dumps(payload), headers=headers)

# %%
payload = {'key1': 'value1', 'key2': 'value2'} 
response = requests.post("http://httpbin.org/post", data=payload) 
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.9.1"
#   },
#   "json": null,
#   "origin": "93.175.2.59",
#   "url": "http://httpbin.org/post"
# }

# %%
url = 'https://api.github.com/some/endpoint' 
payload = {'some': 'data'}
response = requests.post(url, data=json.dumps(payload))

# %%
url = 'http://httpbin.org/post' 
files = {'file': open('untitled.txt', 'rb')}
response = requests.post(url, files=files) 
response.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {\n    "file": ""\n  }, \n  "form": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "148", \n    "Content-Type": "multipart/form-data; boundary=a855300db6fe4490bffff4c2b1b10390", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.9.1"\n  }, \n  "json": null, \n  "origin": "93.175.2.59", \n  "url": "http://httpbin.org/post"\n}\n'

# %%
response = requests.get('http://httpbin.org/get') 
response.status_code
# Out:
# 200

# %%
 response.status_code == requests.codes.ok
# Out:
# True

# %%
response.raise_for_status()

# %%
response.headers
# Out:
# {'Connection': 'keep-alive', 'Date': 'Mon, 22 Feb 2016 19:42:51 GMT', 'Server': 'nginx', 'Content-Type': 'application/json', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'Content-Length': '235'}

# %%
r.headers.get('content-type')
# Out:
# 'application/json; charset=utf-8'

# %%
url = 'http://httpbin.org/cookies' 
cookies = dict(cookies_are='working')
response = requests.get(url, cookies=cookies) 
response.text
# Out:
# '{\n  "cookies": {\n    "cookies_are": "working"\n  }\n}\n'

# %%
response = requests.get('http://github.com') 
response.url 
response.status_code
# Out:
# 200

# %%
response.history
# Out:
# [<Response [301]>]
